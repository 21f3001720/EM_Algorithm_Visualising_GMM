# %%
#import requred libraries
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.stats import multivariate_normal
from scipy.stats import norm
import warnings
import random

warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 #import requred libraries
# ----> 2 import seaborn as sns
#       3 import matplotlib.pyplot as plt
#       4 import numpy as np
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# ...existing code...



# Generate a synthetic dataset with 3 clusters
X, y = make_blobs(n_samples=300, centers=3, cluster_std=2.5, random_state=105)

# Plot the dataset
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis', s=50)
plt.title("Synthetic 2D k-Cluster Dataset")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %%
gmm = GaussianMixture(n_components=3, random_state=42, max_iter=1, warm_start=True)

# Plot the EM algorithm's progress
for i in range(1, 11):  # Visualize the first 10 iterations
    gmm.fit(X)  # Fit the model for one iteration
    y_gmm = gmm.predict(X)  # Predict cluster labels
    
    # Plot the dataset with current GMM clustering results
    plt.figure(figsize=(8, 6))
    plt.scatter(X[:, 0], X[:, 1], c=y_gmm, cmap='viridis', s=50, marker='o', label='GMM Clusters')
    plt.scatter(gmm.means_[:, 0], gmm.means_[:, 1], c='red', s=200, marker='X', label='Cluster Centers')
    
    # Plot the Gaussian components as ellipses
    for j in range(gmm.n_components):
        mean = gmm.means_[j]
        cov = gmm.covariances_[j]
        
        # Handle full covariance matrices
        if cov.ndim == 2:
            eigenvalues, eigenvectors = np.linalg.eigh(cov)
            axis_length = 2 * np.sqrt(eigenvalues)  # 2 standard deviations
            angle = np.arctan2(eigenvectors[0, 1], eigenvectors[0, 0])
            ellipse = plt.matplotlib.patches.Ellipse(mean, axis_length[0], axis_length[1], np.degrees(angle), 
                              edgecolor='blue', facecolor='none', linewidth=2)
            plt.gca().add_patch(ellipse)
    
    plt.title(f"GMM Clustering - Iteration {i}")
    plt.xlabel("Feature 1")
    plt.ylabel("Feature 2")
    plt.legend()
    plt.show()
# Out:
# d:\IIST_SEM_2\StatisticalModels&Analysis\presentstion\.venv\Lib\site-packages\sklearn\mixture\_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 23
#      21         axis_length = 2 * np.sqrt(eigenvalues)  # 2 standard deviations
#      22         angle = np.arctan2(eigenvectors[0, 1], eigenvectors[0, 0])
# ---> 23         ellipse = plt.matplotlib.patches.Ellipse(mean, axis_length[0], axis_length[1], np.degrees(angle),
#      24                           edgecolor='blue', facecolor='none', linewidth=2)
#      25         plt.gca().add_patch(ellipse)
#      27 plt.title(f"GMM Clustering - Iteration {i}")
#
# ...
